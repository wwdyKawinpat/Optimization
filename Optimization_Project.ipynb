# %%
# !pip install -U pandasql
# !pip install amplpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from pandasql) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from pandasql) (1.4.4)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.9/dist-packages (from pandasql) (1.4.46)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->pandasql) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy->pandasql) (2.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->pandasql) (1.15.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26784 sha256=4ea3cb6fe967c4ea56ce2af35d68b537f1309c344016b0e5b1a45043b603f52e
#   Stored in directory: /root/.cache/pip/wheels/63/e8/ec/75b1df467ecf57b6ececb32cb16f4e86697cbfe55cb0c51f07
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting amplpy
#   Downloading amplpy-0.9.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 45.7 MB/s eta 0:00:00
# Collecting ampltools>=0.5.1
#   Downloading ampltools-0.5.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: future>=0.15.0 in /usr/local/lib/python3.9/dist-packages (from amplpy) (0.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from ampltools>=0.5.1->amplpy) (2.25.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->ampltools>=0.5.1->amplpy) (1.26.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->ampltools>=0.5.1->amplpy) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->ampltools>=0.5.1->amplpy) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->ampltools>=0.5.1->amplpy) (2022.12.7)
# Installing collected packages: ampltools, amplpy
# Successfully installed amplpy-0.9.0 ampltools-0.5.1

# %%
import os
import sys
import pandas as pd
import sqlite3
import numpy as np
from amplpy import AMPL
from pandasql import sqldf
from sklearn import datasets
#pd.set_option('display.max_rows',None)

# %%
from amplpy import AMPL, tools
ampl = tools.ampl_notebook(
    modules=["cplex"],          # modules to install
    license_uuid="default",     # license to use
    g=globals())                # instantiate AMPL object and register magics
# Out:
# VBox(children=(Output(), HBox(children=(Button(description='Use existing license', style=ButtonStyle()), Text(…

# %%
con = sqlite3.connect("data.db")

# %%
cur = con.cursor()
table = pd.DataFrame(cur.execute("SELECT name FROM sqlite_master WHERE type='table'"))
table.reset_index(drop=True, inplace=True)
table = table[0]
table = table.loc[0:]
print(table)
# Out:
# 0       data
# 1      y3_fm
# 2      y5_fm
# 3      y8_fm
# 4       y8_m
# 5     y12_fm
# 6      y12_m
# 7     y15_fm
# 8      y15_m
# 9     y18_fm
# 10     y18_m
# 11    y30_fm
# 12     y30_m
# 13    y50_fm
# 14     y50_m
# 15    y60_fm
# 16     y60_m
# 17    y70_fm
# 18     y70_m
# 19    y71_fm
# 20     y71_m
# 21      y3_m
# 22      y5_m
# Name: 0, dtype: object

# %%
table_name = []
for i in table:
    exec('{} = pd.read_sql_query(("select * from " + i),con)'.format(i))
    table_name.append(i)
table_name
# Out:
# ['data',
#  'y3_fm',
#  'y5_fm',
#  'y8_fm',
#  'y8_m',
#  'y12_fm',
#  'y12_m',
#  'y15_fm',
#  'y15_m',
#  'y18_fm',
#  'y18_m',
#  'y30_fm',
#  'y30_m',
#  'y50_fm',
#  'y50_m',
#  'y60_fm',
#  'y60_m',
#  'y70_fm',
#  'y70_m',
#  'y71_fm',
#  'y71_m',
#  'y3_m',
#  'y5_m']

# %%
# Nutrition dataframe for female
y3_carb_new = pd.DataFrame(y3_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y3_fm = y3_fm.append(y3_carb_new)
y3_fm = y3_fm.drop([y3_fm.index[2],y3_fm.index[3],y3_fm.index[4],y3_fm.index[5]])
y3_fm = y3_fm.fillna("carb")
y3_fm.columns = ["nutr","m_min","m_max"]
y3_fm = y3_fm.set_index(["nutr"])
y3_fm = y3_fm.div(3)

y5_carb_new = pd.DataFrame(y5_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y5_fm = y5_fm.append(y5_carb_new)
y5_fm = y5_fm.drop([y5_fm.index[2],y5_fm.index[3],y5_fm.index[4],y5_fm.index[5]])
y5_fm = y5_fm.fillna("carb")
y5_fm.columns = ["nutr","m_min","m_max"]
y5_fm = y5_fm.set_index(["nutr"])
y5_fm = y5_fm.div(3)

y8_carb_new = pd.DataFrame(y8_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y8_fm = y8_fm.append(y8_carb_new)
y8_fm = y8_fm.drop([y8_fm.index[2],y8_fm.index[3],y8_fm.index[4],y8_fm.index[5]])
y8_fm = y8_fm.fillna("carb")
y8_fm.columns = ["nutr","m_min","m_max"]
y8_fm = y8_fm.set_index(["nutr"])
y8_fm =y8_fm.div(3)

y12_carb_new = pd.DataFrame(y12_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y12_fm = y12_fm.append(y12_carb_new)
y12_fm = y12_fm.drop([y12_fm.index[2],y12_fm.index[3],y12_fm.index[4],y12_fm.index[5]])
y12_fm = y12_fm.fillna("carb")
y12_fm.columns = ["nutr","m_min","m_max"]
y12_fm = y12_fm.set_index(["nutr"])
y12_fm =y12_fm.div(3)

y15_carb_new = pd.DataFrame(y15_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y15_fm = y15_fm.append(y15_carb_new)
y15_fm = y15_fm.drop([y15_fm.index[2],y15_fm.index[3],y15_fm.index[4],y15_fm.index[5]])
y15_fm = y15_fm.fillna("carb")
y15_fm.columns = ["nutr","m_min","m_max"]
y15_fm = y15_fm.set_index(["nutr"])
y15_fm = y15_fm.div(3)

y18_carb_new = pd.DataFrame(y18_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y18_fm = y18_fm.append(y18_carb_new)
y18_fm = y18_fm.drop([y18_fm.index[2],y18_fm.index[3],y18_fm.index[4],y18_fm.index[5]])
y18_fm = y18_fm.fillna("carb")
y18_fm.columns = ["nutr","m_min","m_max"]
y18_fm = y18_fm.set_index(["nutr"])
y18_fm = y18_fm.div(3)

y30_carb_new = pd.DataFrame(y30_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y30_fm = y30_fm.append(y30_carb_new)
y30_fm = y30_fm.drop([y30_fm.index[2],y30_fm.index[3],y30_fm.index[4],y30_fm.index[5]])
y30_fm = y30_fm.fillna("carb")
y30_fm.columns = ["nutr","m_min","m_max"]
y30_fm = y30_fm.set_index(["nutr"])
y30_fm = y30_fm.div(3)

y50_carb_new = pd.DataFrame(y50_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y50_fm = y50_fm.append(y50_carb_new)
y50_fm = y50_fm.drop([y50_fm.index[2],y50_fm.index[3],y50_fm.index[4],y50_fm.index[5]])
y50_fm = y50_fm.fillna("carb")
y50_fm.columns = ["nutr","m_min","m_max"]
y50_fm = y50_fm.set_index(["nutr"])
y50_fm = y50_fm.div(3)

y60_carb_new = pd.DataFrame(y60_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y60_fm = y60_fm.append(y60_carb_new)
y60_fm = y60_fm.drop([y60_fm.index[2],y60_fm.index[3],y60_fm.index[4],y60_fm.index[5]])
y60_fm = y60_fm.fillna("carb")
y60_fm.columns = ["nutr","m_min","m_max"]
y60_fm = y60_fm.set_index(["nutr"])
y60_fm = y60_fm.div(3)

y70_carb_new = pd.DataFrame(y70_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y70_fm = y70_fm.append(y70_carb_new)
y70_fm = y70_fm.drop([y70_fm.index[2],y70_fm.index[3],y70_fm.index[4],y70_fm.index[5]])
y70_fm = y70_fm.fillna("carb")
y70_fm.columns = ["nutr","m_min","m_max"]
y70_fm = y70_fm.set_index(["nutr"])
y70_fm = y70_fm.div(3)

y71_carb_new = pd.DataFrame(y71_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y71_fm = y71_fm.append(y71_carb_new)
y71_fm = y71_fm.drop([y71_fm.index[2],y71_fm.index[3],y71_fm.index[4],y71_fm.index[5]])
y71_fm = y71_fm.fillna("carb")
y71_fm.columns = ["nutr","m_min","m_max"]
y71_fm = y71_fm.set_index(["nutr"])
y71_fm = y71_fm.div(3)
# Out:
# <ipython-input-52-72f1694c3a94>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y3_carb_new = pd.DataFrame(y3_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-52-72f1694c3a94>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y3_fm = y3_fm.append(y3_carb_new)
# <ipython-input-52-72f1694c3a94>:10: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y5_carb_new = pd.DataFrame(y5_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-52-72f1694c3a94>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y5_fm = y5_fm.append(y5_carb_new)
# <ipython-input-52-72f1694c3a94>:18: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y8_carb_new = pd.DataFrame(y8_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-52-72f1694c3a94>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y8_fm = y8_fm.append(y8_carb_new)
# <ipython-input-52-72f1694c3a94>:26: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y12_carb_new = pd.DataFrame(y12_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-52-72f1694c3a94>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y12_fm = y12_fm.append(y12_carb_new)
# <ipython-input-52-72f1694c3a94>:34: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y15_carb_new = pd.DataFrame(y15_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-52-72f1694c3a94>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y15_fm = y15_fm.append(y15_carb_new)
# <ipython-input-52-72f1694c3a94>:42: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y18_carb_new = pd.DataFrame(y18_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-52-72f1694c3a94>:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y18_fm = y18_fm.append(y18_carb_new)
# <ipython-input-52-72f1694c3a94>:50: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y30_carb_new = pd.DataFrame(y30_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-52-72f1694c3a94>:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y30_fm = y30_fm.append(y30_carb_new)
# <ipython-input-52-72f1694c3a94>:58: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y50_carb_new = pd.DataFrame(y50_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-52-72f1694c3a94>:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y50_fm = y50_fm.append(y50_carb_new)
# <ipython-input-52-72f1694c3a94>:66: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y60_carb_new = pd.DataFrame(y60_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-52-72f1694c3a94>:67: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y60_fm = y60_fm.append(y60_carb_new)
# <ipython-input-52-72f1694c3a94>:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y70_carb_new = pd.DataFrame(y70_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-52-72f1694c3a94>:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y70_fm = y70_fm.append(y70_carb_new)
# <ipython-input-52-72f1694c3a94>:82: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y71_carb_new = pd.DataFrame(y71_fm.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-52-72f1694c3a94>:83: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y71_fm = y71_fm.append(y71_carb_new)

# %%
# Nutrition datafram for male
y3_carb_new = pd.DataFrame(y3_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y3_m = y3_m.append(y3_carb_new)
y3_m = y3_m.drop([y3_m.index[2],y3_m.index[3],y3_m.index[4],y3_m.index[5]])
y3_m = y3_m.fillna("carb")
y3_m.columns = ["nutr","m_min","m_max"]
y3_m = y3_m.set_index(["nutr"])
y3_m = y3_m.div(3)

y5_carb_new = pd.DataFrame(y5_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y5_m = y5_m.append(y5_carb_new)
y5_m = y5_m.drop([y5_m.index[2],y5_m.index[3],y5_m.index[4],y5_m.index[5]])
y5_m = y5_m.fillna("carb")
y5_m.columns = ["nutr","m_min","m_max"]
y5_m = y5_m.set_index(["nutr"])
y5_m = y5_m.div(3)

y8_carb_new_m = pd.DataFrame(y8_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y8_m = y8_m.append(y8_carb_new_m)
y8_m = y8_m.drop([y8_m.index[2],y8_m.index[3],y8_m.index[4],y8_m.index[5]])
y8_m = y8_m.fillna("carb")
y8_m.columns = ["nutr","m_min","m_max"]
y8_m = y8_m.set_index(["nutr"])
y8_m = y8_m.div(3)

y12_carb_new = pd.DataFrame(y12_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y12_m = y12_m.append(y12_carb_new)
y12_m = y12_m.drop([y12_m.index[2],y12_m.index[3],y12_m.index[4],y12_m.index[5]])
y12_m = y12_m.fillna("carb")
y12_m.columns = ["nutr","m_min","m_max"]
y12_m = y12_m.set_index(["nutr"])
y12_m = y12_m.div(3)

y15_carb_new = pd.DataFrame(y15_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y15_m = y15_m.append(y15_carb_new)
y15_m = y15_m.drop([y15_m.index[2],y15_m.index[3],y15_m.index[4],y15_m.index[5]])
y15_m = y15_m.fillna("carb")
y15_m.columns = ["nutr","m_min","m_max"]
y15_m = y15_m.set_index(["nutr"])
y15_m = y15_m.div(3)

y18_carb_new = pd.DataFrame(y18_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y18_m = y18_m.append(y18_carb_new)
y18_m = y18_m.drop([y18_m.index[2],y18_m.index[3],y18_m.index[4],y18_m.index[5]])
y18_m = y18_m.fillna("carb")
y18_m.columns = ["nutr","m_min","m_max"]
y18_m = y18_m.set_index(["nutr"])
y18_m = y18_m.div(3)

y30_carb_new = pd.DataFrame(y30_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y30_m = y30_m.append(y30_carb_new)
y30_m = y30_m.drop([y30_m.index[2],y30_m.index[3],y30_m.index[4],y30_m.index[5]])
y30_m = y30_m.fillna("carb")
y30_m.columns = ["nutr","m_min","m_max"]
y30_m = y30_m.set_index(["nutr"])
y30_m = y30_m.div(3)

y50_carb_new = pd.DataFrame(y50_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y50_m = y50_m.append(y50_carb_new)
y50_m = y50_m.drop([y50_m.index[2],y50_m.index[3],y50_m.index[4],y50_m.index[5]])
y50_m = y50_m.fillna("carb")
y50_m.columns = ["nutr","m_min","m_max"]
y50_m = y50_m.set_index(["nutr"])
y50_m = y50_m.div(3)

y60_carb_new = pd.DataFrame(y60_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y60_m = y60_m.append(y60_carb_new)
y60_m = y60_m.drop([y60_m.index[2],y60_m.index[3],y60_m.index[4],y60_m.index[5]])
y60_m = y60_m.fillna("carb")
y60_m.columns = ["nutr","m_min","m_max"]
y60_m = y60_m.set_index(["nutr"])
y60_m = y60_m.div(3)

y70_carb_new = pd.DataFrame(y70_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y70_m = y70_m.append(y70_carb_new)
y70_m = y70_m.drop([y70_m.index[2],y70_m.index[3],y70_m.index[4],y70_m.index[5]])
y70_m = y70_m.fillna("carb")
y70_m.columns = ["nutr","m_min","m_max"]
y70_m = y70_m.set_index(["nutr"])
y70_m = y70_m.div(3)

y71_carb_new = pd.DataFrame(y71_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
y71_m = y71_m.append(y71_carb_new)
y71_m = y71_m.drop([y71_m.index[2],y71_m.index[3],y71_m.index[4],y71_m.index[5]])
y71_m = y71_m.fillna("carb")
y71_m.columns = ["nutr","m_min","m_max"]
y71_m = y71_m.set_index(["nutr"])
y71_m = y71_m.div(3)
# Out:
# <ipython-input-53-e26c3206dc96>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y3_carb_new = pd.DataFrame(y3_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-53-e26c3206dc96>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y3_m = y3_m.append(y3_carb_new)
# <ipython-input-53-e26c3206dc96>:10: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y5_carb_new = pd.DataFrame(y5_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-53-e26c3206dc96>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y5_m = y5_m.append(y5_carb_new)
# <ipython-input-53-e26c3206dc96>:18: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y8_carb_new_m = pd.DataFrame(y8_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-53-e26c3206dc96>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y8_m = y8_m.append(y8_carb_new_m)
# <ipython-input-53-e26c3206dc96>:26: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y12_carb_new = pd.DataFrame(y12_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-53-e26c3206dc96>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y12_m = y12_m.append(y12_carb_new)
# <ipython-input-53-e26c3206dc96>:34: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y15_carb_new = pd.DataFrame(y15_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-53-e26c3206dc96>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y15_m = y15_m.append(y15_carb_new)
# <ipython-input-53-e26c3206dc96>:42: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y18_carb_new = pd.DataFrame(y18_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-53-e26c3206dc96>:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y18_m = y18_m.append(y18_carb_new)
# <ipython-input-53-e26c3206dc96>:50: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y30_carb_new = pd.DataFrame(y30_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-53-e26c3206dc96>:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y30_m = y30_m.append(y30_carb_new)
# <ipython-input-53-e26c3206dc96>:58: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y50_carb_new = pd.DataFrame(y50_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-53-e26c3206dc96>:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y50_m = y50_m.append(y50_carb_new)
# <ipython-input-53-e26c3206dc96>:66: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y60_carb_new = pd.DataFrame(y60_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-53-e26c3206dc96>:67: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y60_m = y60_m.append(y60_carb_new)
# <ipython-input-53-e26c3206dc96>:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y70_carb_new = pd.DataFrame(y70_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-53-e26c3206dc96>:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y70_m = y70_m.append(y70_carb_new)
# <ipython-input-53-e26c3206dc96>:82: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   y71_carb_new = pd.DataFrame(y71_m.iloc[2:6,:].mean(), index = ["min","max"]).transpose()
# <ipython-input-53-e26c3206dc96>:83: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y71_m = y71_m.append(y71_carb_new)

# %%
data = cur.execute("select * from data")
data = pd.DataFrame(data, columns =['id','p_name','cal','fat(g)','fat','carb','protein','sodium','quantity','unit','price','ptype_no','ptype','mor','aft','even'])

# %%
#data.head()

# %%
morning = data.loc[data['mor'] == 1]
afternoon = data.loc[data['aft'] == 1]
evening = data.loc[data['even'] == 1]

# %%
food_df = pd.DataFrame(data.iloc[:, [0,10]]).set_index(["id"])
#food_df
# Out:
#      price
# id
# 1     17.0
# 2     10.0
# 3     39.0
# 4     16.0
# 5     20.0
# ..     ...
# 344   20.0
# 345   30.0
# 346   99.0
# 347  105.0
# 348   89.0
#
# [348 rows x 1 columns]

# %%
food_df1 = pd.DataFrame(morning.iloc[:, [0,10]]).set_index(["id"])
food_df2 = pd.DataFrame(afternoon.iloc[:, [0,10]]).set_index(["id"])
food_df3 = pd.DataFrame(evening.iloc[:, [0,10]]).set_index(["id"])

# %%
amt_df1 = pd.DataFrame(morning.iloc[:, [0,2,4,5,6,7]]).set_index(["id"])
amt_df2 = pd.DataFrame(afternoon.iloc[:, [0,2,4,5,6,7]]).set_index(["id"])
amt_df3 = pd.DataFrame(evening.iloc[:, [0,2,4,5,6,7]]).set_index(["id"])

# %%
#new input
while True : 
    iter = input("Please enter # of day: ")
    try:
        iter = int(iter)
        if iter >= 1 and iter <= 10:
            break
        else:
            print("Invalid day. Please enter day between 1 and 10.")
    except ValueError:
        print("Invalid input. Please enter a # of day.")
        
while True : 
    age = input("Please enter your age: ")
    try:
        age = int(age)
        if age > 0 and age <= 120:
            break
        else:
            print("Invalid age. Please enter an age between 0 and 120.")
    except ValueError:
        print("Invalid input. Please enter a valid age.")
name = input("What is your name? : ")
print("Hello " + name + "! To calculate your appropriate nutrition, PLEASE SUBMIT YOUR AGE AND YOUR GENER.")

gender = input("Please enter your sex (type 'm' or 'f' ): ")
while gender not in ['m', 'f']:
    gender = input("Invalid input. Please enter 'm' or 'f': ")

while True : 
    pdf = input("Please enter your budget: ")
    try:
        pdf = int(pdf)
        if pdf >= 100 and pdf <= 1000:
            break
        else:
            print("Invalid budget. Please enter an budget between 100 and 500.")
    except ValueError:
        print("Invalid input. Please enter a valid budget.")
# Out:
# Please enter # of day: 7
# Please enter your age: 0
# Invalid age. Please enter an age between 0 and 120.
# Please enter your age: 1
# What is your name? : u
# Hello u! To calculate your appropriate nutrition, PLEASE SUBMIT YOUR AGE AND YOUR GENER.
# Please enter your sex (type 'm' or 'f' ): m
# Please enter your budget: 200

# %%
#iter = int(input("# of day: "))
 # Send the data from "nutr_df" to AMPL and initialize the indexing set "NUTR"
#name = input("What is your name? : ")
#print("Hello " + name + "! To calculate your appropriate nutrition, PLEASE SUBMIT YOUR AGE AND YOUR GENER.")
#age = int(input("Please input your age : "))
#gender = input("Please input your gender (m/f): ")
#pdf = int(input("Enter your Budget: "))

i = 1

for i in range(i, iter+1) :
  print ("--------------------------- Day ", i, " ---------------------------")

  ampl.eval(
      r"""
      reset;
      option solver cplex;

      set nutr;
      set id;

      param price {id} > 0;
      param pdf >= 0;
      param m_min {nutr} >= 0;
      param m_max {i in nutr} >= m_min[i];

      param amt {nutr,id} >= 0;

      var Buy {j in id} integer >= 0;

      minimize Total_Cost:  sum {j in id} price[j] * Buy[j];

      subject to Diet {i in nutr}: m_min[i] <= sum {j in id} amt[i,j] * Buy[j] <= m_max[i];
      subject to const1 : sum {j in id} price[j] * Buy[j] <= pdf;""")

  # nutrition condition for male
  if gender == 'm' :
      if age <= 3 :
          ampl.set_data(y3_m, "nutr")
      elif age <= 5 :
          ampl.set_data(y5_m, "nutr")
      elif age <= 8 :
          ampl.set_data(y8_m, "nutr")
      elif age <= 12 :
          ampl.set_data(y12_m, "nutr")
      elif age <= 15 :
          ampl.set_data(y15_m, "nutr")
      elif age <= 18 :
          ampl.set_data(y18_m, "nutr")
      elif age <= 30 :
          ampl.set_data(y30_m, "nutr")
      elif age <= 50 :
          ampl.set_data(y50_m, "nutr")
      elif age <= 60 :
          ampl.set_data(y60_m, "nutr")
      elif age <= 70 :
          ampl.set_data(y70_m, "nutr")
      elif age >= 71 :
          ampl.set_data(y71_m, "nutr") 

  # nutrition condition for female
  elif gender == 'fm' :
      if age <= 3 :
          ampl.set_data(y3_fm, "nutr")
      elif age <= 5 :
          ampl.set_data(y5_fm, "nutr")
      elif age <= 8 :
          ampl.set_data(y8_fm, "nutr")
      elif age <= 12 :
          ampl.set_data(y12_fm, "nutr")
      elif age <= 15 :
          ampl.set_data(y15_fm, "nutr")
      elif age <= 18 :
          ampl.set_data(y18_fm, "nutr")
      elif age <= 30 :
          ampl.set_data(y30_fm, "nutr")
      elif age <= 50 :
          ampl.set_data(y50_fm, "nutr")
      elif age <= 60 :
          ampl.set_data(y60_fm, "nutr")
      elif age <= 70 :
          ampl.set_data(y70_fm, "nutr")
      elif age >= 71 :
          ampl.set_data(y71_fm, "nutr") 
  
  # Send the data from "amt_df" to AMPL and initialize the indexing set "FOOD"
  ampl.set_data(food_df1, "id")
  # Set the values for the parameter "amt" using "amt_df"
  ampl.get_parameter("amt").set_values(amt_df1.unstack())

  ampl.get_parameter("pdf").set_values([pdf])

  # Specify the solver to use (e.g., HiGHS)
  ampl.option["solver"] = "cplex"
  # Solve
  ampl.solve()
  # Stop if the model was not solved
  assert ampl.get_value("solve_result") == "solved"
  # Get objective entity by AMPL name
  totalcost = ampl.get_objective('Total_Cost')
  # Print it
  print("Objective is:", totalcost.value())
  
  print("---------------------------Breakfast---------------------------")
  b_values = ampl.get_variable('Buy').get_values()
  b_values = pd.DataFrame(b_values)
  b_values.columns = ['id', 'amount(unit)']
  result_n = b_values.loc[b_values['amount(unit)'] !=0]
  result = data.merge(result_n, on = ["id"],how = "inner" )
  result = pd.DataFrame(result.iloc[:, [1,2,4,5,6,7,16]])
  print(result.to_markdown(tablefmt="rst"))
  food_df1 = food_df1.drop(result_n['id'])
  amt_df1 = amt_df1.drop(result_n['id'])

  ampl.eval(
      r"""
      reset;
      option solver cplex;

      set nutr;
      set id;

      param price {id} > 0;
      param pdf >= 0;
      param m_min {nutr} >= 0;
      param m_max {i in nutr} >= m_min[i];

      param amt {nutr,id} >= 0;

      var Buy {j in id} integer >= 0;

      minimize Total_Cost:  sum {j in id} price[j] * Buy[j];

      subject to Diet {i in nutr}: m_min[i] <= sum {j in id} amt[i,j] * Buy[j] <= m_max[i];
      subject to const1 : sum {j in id} price[j] * Buy[j] <= pdf;""")

  # nutrition condition for male
  if gender == 'm' :
      if age <= 3 :
          ampl.set_data(y3_m, "nutr")
      elif age <= 5 :
          ampl.set_data(y5_m, "nutr")
      elif age <= 8 :
          ampl.set_data(y8_m, "nutr")
      elif age <= 12 :
          ampl.set_data(y12_m, "nutr")
      elif age <= 15 :
          ampl.set_data(y15_m, "nutr")
      elif age <= 18 :
          ampl.set_data(y18_m, "nutr")
      elif age <= 30 :
          ampl.set_data(y30_m, "nutr")
      elif age <= 50 :
          ampl.set_data(y50_m, "nutr")
      elif age <= 60 :
          ampl.set_data(y60_m, "nutr")
      elif age <= 70 :
          ampl.set_data(y70_m, "nutr")
      elif age >= 71 :
          ampl.set_data(y71_m, "nutr") 

  # nutrition condition for female
  elif gender == 'fm' :
      if age <= 3 :
          ampl.set_data(y3_fm, "nutr")
      elif age <= 5 :
          ampl.set_data(y5_fm, "nutr")
      elif age <= 8 :
          ampl.set_data(y8_fm, "nutr")
      elif age <= 12 :
          ampl.set_data(y12_fm, "nutr")
      elif age <= 15 :
          ampl.set_data(y15_fm, "nutr")
      elif age <= 18 :
          ampl.set_data(y18_fm, "nutr")
      elif age <= 30 :
          ampl.set_data(y30_fm, "nutr")
      elif age <= 50 :
          ampl.set_data(y50_fm, "nutr")
      elif age <= 60 :
          ampl.set_data(y60_fm, "nutr")
      elif age <= 70 :
          ampl.set_data(y70_fm, "nutr")
      elif age >= 71 :
          ampl.set_data(y71_fm, "nutr") 
  
  # 1. Send the data from "amt_df" to AMPL and initialize the indexing set "FOOD"
  ampl.set_data(food_df2, "id")
  # 3. Set the values for the parameter "amt" using "amt_df"
  ampl.get_parameter("amt").set_values(amt_df2.unstack())

  ampl.get_parameter("pdf").set_values([pdf])

  # Specify the solver to use 
  ampl.option["solver"] = "cplex"
  # Solve
  ampl.solve()
  # Stop if the model was not solved
  assert ampl.get_value("solve_result") == "solved"
  # Get objective entity by AMPL name
  totalcost = ampl.get_objective('Total_Cost')
  # Print it
  print("Objective is:", totalcost.value())
  
  print("---------------------------Lunch---------------------------")
  b_values = ampl.get_variable('Buy').get_values()
  b_values = pd.DataFrame(b_values)
  b_values.columns = ['id', 'amount(unit)']
  result_n = b_values.loc[b_values['amount(unit)'] !=0]
  result = data.merge(result_n, on = ["id"],how = "inner" )
  result = pd.DataFrame(result.iloc[:, [1,2,4,5,6,7,16]])
  print(result.to_markdown(tablefmt="rst"))
  food_df2 = food_df2.drop(result_n['id'])
  amt_df2 = amt_df2.drop(result_n['id'])

  ampl.eval(
      r"""
      reset;
      option solver cplex;

      set nutr;
      set id;

      param price {id} > 0;
      param pdf >= 0;
      param m_min {nutr} >= 0;
      param m_max {i in nutr} >= m_min[i];

      param amt {nutr,id} >= 0;

      var Buy {j in id} integer >= 0;

      minimize Total_Cost:  sum {j in id} price[j] * Buy[j];

      subject to Diet {i in nutr}: m_min[i] <= sum {j in id} amt[i,j] * Buy[j] <= m_max[i];
      subject to const1 : sum {j in id} price[j] * Buy[j] <= pdf;""")

  # nutrition condition for male
  if gender == 'm' :
      if age <= 3 :
          ampl.set_data(y3_m, "nutr")
      elif age <= 5 :
          ampl.set_data(y5_m, "nutr")
      elif age <= 8 :
          ampl.set_data(y8_m, "nutr")
      elif age <= 12 :
          ampl.set_data(y12_m, "nutr")
      elif age <= 15 :
          ampl.set_data(y15_m, "nutr")
      elif age <= 18 :
          ampl.set_data(y18_m, "nutr")
      elif age <= 30 :
          ampl.set_data(y30_m, "nutr")
      elif age <= 50 :
          ampl.set_data(y50_m, "nutr")
      elif age <= 60 :
          ampl.set_data(y60_m, "nutr")
      elif age <= 70 :
          ampl.set_data(y70_m, "nutr")
      elif age >= 71 :
          ampl.set_data(y71_m, "nutr") 

  # nutrition condition for female
  elif gender == 'fm' :
      if age <= 3 :
          ampl.set_data(y3_fm, "nutr")
      elif age <= 5 :
          ampl.set_data(y5_fm, "nutr")
      elif age <= 8 :
          ampl.set_data(y8_fm, "nutr")
      elif age <= 12 :
          ampl.set_data(y12_fm, "nutr")
      elif age <= 15 :
          ampl.set_data(y15_fm, "nutr")
      elif age <= 18 :
          ampl.set_data(y18_fm, "nutr")
      elif age <= 30 :
          ampl.set_data(y30_fm, "nutr")
      elif age <= 50 :
          ampl.set_data(y50_fm, "nutr")
      elif age <= 60 :
          ampl.set_data(y60_fm, "nutr")
      elif age <= 70 :
          ampl.set_data(y70_fm, "nutr")
      elif age >= 71 :
          ampl.set_data(y71_fm, "nutr") 
  
  # 1. Send the data from "amt_df" to AMPL and initialize the indexing set "FOOD"
  ampl.set_data(food_df3, "id")
  # 3. Set the values for the parameter "amt" using "amt_df"
  ampl.get_parameter("amt").set_values(amt_df3.unstack())

  ampl.get_parameter("pdf").set_values([pdf])

  # Specify the solver to use
  ampl.option["solver"] = "cplex"
  # Solve
  ampl.solve()
  # Stop if the model was not solved
  assert ampl.get_value("solve_result") == "solved"
  # Get objective entity by AMPL name
  totalcost = ampl.get_objective('Total_Cost')
  # Print it
  print("Objective is:", totalcost.value())

  print("---------------------------Dinner---------------------------")
  b_values = ampl.get_variable('Buy').get_values()
  b_values = pd.DataFrame(b_values)
  b_values.columns = ['id', 'amount(unit)']
  result_n = b_values.loc[b_values['amount(unit)'] !=0]
  result = data.merge(result_n, on = ["id"],how = "inner" )
  result = pd.DataFrame(result.iloc[:, [1,2,4,5,6,7,16]])
  print(result.to_markdown(tablefmt="rst"))
  food_df3 = food_df3.drop(result_n['id'])
  amt_df3 = amt_df3.drop(result_n['id'])
# Out:
# --------------------------- Day  1  ---------------------------
# CPLEX 22.1.1.0: optimal integer solution; objective 37.25
# 70 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 37.25
# ---------------------------Breakfast---------------------------
# ====  ====================================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                                  cal    fat    carb    protein    sodium    amount(unit)
# ====  ====================================  =====  =====  ======  =========  ========  ==============
#    0  ไทย-เดนมาร์คนมยูเอชทีรสจืด                  130     72       7          8        80               1
#    1  เพียวริคุชาขาวน้ำเก๊กฮวยขาวพร้อมดื่มผสมชาขาว     80      0      20          0        30               1
#    2  เมจินมพาสเจอร์ไรส์กลิ่นกล้วย                  140     45      19          5       100               1
# ====  ====================================  =====  =====  ======  =========  ========  ==============
# CPLEX 22.1.1.0: optimal integer solution; objective 35
# 32 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 35.0
# ---------------------------Lunch---------------------------
# ====  =========================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                       cal    fat    carb    protein    sodium    amount(unit)
# ====  =========================  =====  =====  ======  =========  ========  ==============
#    0  กูลิโกะป๊อกกี้รสคุกกี้และครีม         220     81      32          3        75               1
#    1  โยเกิร์ตเมจิรสองุ่นผสมวุ้นมะพร้าว    130     27      21          4        65               1
# ====  =========================  =====  =====  ======  =========  ========  ==============
# CPLEX 22.1.1.0: optimal integer solution; objective 35
# 59 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 35.0
# ---------------------------Dinner---------------------------
# ====  =========================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                       cal    fat    carb    protein    sodium    amount(unit)
# ====  =========================  =====  =====  ======  =========  ========  ==============
#    0  กูลิโกะป๊อกกี้รสคุกกี้และครีม         220     81      32          3        75               1
#    1  โยเกิร์ตเมจิรสองุ่นผสมวุ้นมะพร้าว    130     27      21          4        65               1
# ====  =========================  =====  =====  ======  =========  ========  ==============
# --------------------------- Day  2  ---------------------------
# CPLEX 22.1.1.0: optimal integer solution; objective 38
# 55 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 38.0
# ---------------------------Breakfast---------------------------
# ====  =============================================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                                           cal    fat    carb    protein    sodium    amount(unit)
# ====  =============================================  =====  =====  ======  =========  ========  ==============
#    0  ดัชมิลล์โยเกิร์ตพร้อมดื่ม4in1ไมโครแอคทีฟรสเบอร์รี่รวม4ชนิด    160     27      32          3        60               1
#    1  ฟาร์มเฮ้าส์โดรายากิไส้คัสตาร์ดครีม                       190     45      32          3       160               1
# ====  =============================================  =====  =====  ======  =========  ========  ==============
# CPLEX 22.1.1.0: optimal integer solution; objective 37
# 166 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 37.0
# ---------------------------Lunch---------------------------
# ====  =============================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                           cal    fat    carb    protein    sodium    amount(unit)
# ====  =============================  =====  =====  ======  =========  ========  ==============
#    0  นมเปรี้ยวโยเกิร์ตพร้อมดื่มไพเกนกลิ่นส้ม     60      0      13          1        35               1
#    1  โฟร์โมสต์นมยูเอชทีรสซ็อกโกแลต         190     72      25          5       105               1
#    2  โยเกิร์ตเมจิรสพีชผสมวุ้นมะพร้าว         130     27      22          4        60               1
# ====  =============================  =====  =====  ======  =========  ========  ==============
# CPLEX 22.1.1.0: optimal integer solution; objective 37
# 132 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 37.0
# ---------------------------Dinner---------------------------
# ====  =============================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                           cal    fat    carb    protein    sodium    amount(unit)
# ====  =============================  =====  =====  ======  =========  ========  ==============
#    0  นมเปรี้ยวโยเกิร์ตพร้อมดื่มไพเกนกลิ่นส้ม     60      0      13          1        35               1
#    1  โฟร์โมสต์นมยูเอชทีรสซ็อกโกแลต         190     72      25          5       105               1
#    2  โยเกิร์ตเมจิรสพีชผสมวุ้นมะพร้าว         130     27      22          4        60               1
# ====  =============================  =====  =====  ======  =========  ========  ==============
# --------------------------- Day  3  ---------------------------
# CPLEX 22.1.1.0: optimal integer solution; objective 42
# 75 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 42.0
# ---------------------------Breakfast---------------------------
# ====  =========================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                       cal    fat    carb    protein    sodium    amount(unit)
# ====  =========================  =====  =====  ======  =========  ========  ==============
#    0  ดอยคำน้ำลิ้นจี่๙๘%                120      0      31          0        15               1
#    1  โฟรโมสต์นมยูเอชทีรสสตรอเบอร์รี่    150     63      16          6       120               1
#    2  เลอแปงบานาน่า                 100     45      12          3        45               1
# ====  =========================  =====  =====  ======  =========  ========  ==============
# CPLEX 22.1.1.0: optimal integer solution; objective 38
# 42 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 38.0
# ---------------------------Lunch---------------------------
# ====  ====================================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                                  cal    fat    carb    protein    sodium    amount(unit)
# ====  ====================================  =====  =====  ======  =========  ========  ==============
#    0  กูลิโกะโคลลอนครีม                          140     54      20          1        20               1
#    1  นมเปรี้ยวโยเกิร์ตพร้อมดื่มไพเกนกลิ่นสตรอเบอร์รี่     50      0      12          1        35               1
#    2  โฟรโมสต์นมยูเอชทีรสหวาน                    160     63      20          5       105               1
# ====  ====================================  =====  =====  ======  =========  ========  ==============
# CPLEX 22.1.1.0: optimal integer solution; objective 38
# 42 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 38.0
# ---------------------------Dinner---------------------------
# ====  ====================================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                                  cal    fat    carb    protein    sodium    amount(unit)
# ====  ====================================  =====  =====  ======  =========  ========  ==============
#    0  กูลิโกะโคลลอนครีม                          140     54      20          1        20               1
#    1  นมเปรี้ยวโยเกิร์ตพร้อมดื่มไพเกนกลิ่นสตรอเบอร์รี่     50      0      12          1        35               1
#    2  โฟรโมสต์นมยูเอชทีรสหวาน                    160     63      20          5       105               1
# ====  ====================================  =====  =====  ======  =========  ========  ==============
# --------------------------- Day  4  ---------------------------
# CPLEX 22.1.1.0: optimal integer solution; objective 43
# 49 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 43.0
# ---------------------------Breakfast---------------------------
# ====  =================================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                               cal    fat    carb    protein    sodium    amount(unit)
# ====  =================================  =====  =====  ======  =========  ========  ==============
#    0  ฟาร์มเฮ้าส์สวีทแซนด์วิชแซนด์วิชไส้ช็อกโกแลต    160     63      22          3       115               1
#    1  โยเกิร์ตเมจิมิกซ์เบอร์รี                    120     27      20          4        55               2
# ====  =================================  =====  =====  ======  =========  ========  ==============
# CPLEX 22.1.1.0: optimal integer solution; objective 39
# 37 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 39.0
# ---------------------------Lunch---------------------------
# ====  ===============================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                             cal    fat    carb    protein    sodium    amount(unit)
# ====  ===============================  =====  =====  ======  =========  ========  ==============
#    0  ดอยคำน้ำฝรั่ง๙๘%                      120      0      30          0         0               1
#    1  โฟรโมสต์นมยูเอชทีรสสตรอเบอร์รี่          150     63      16          6       120               1
#    2  เฮอร์ชีส์ครีมมีมิลค์ช็อกโกแลตช็อกโกแลตนม     80     45       8          1        10               1
# ====  ===============================  =====  =====  ======  =========  ========  ==============
# CPLEX 22.1.1.0: optimal integer solution; objective 39
# 43 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 39.0
# ---------------------------Dinner---------------------------
# ====  ===============================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                             cal    fat    carb    protein    sodium    amount(unit)
# ====  ===============================  =====  =====  ======  =========  ========  ==============
#    0  ดอยคำน้ำฝรั่ง๙๘%                      120      0      30          0         0               1
#    1  โฟรโมสต์นมยูเอชทีรสสตรอเบอร์รี่          150     63      16          6       120               1
#    2  เฮอร์ชีส์ครีมมีมิลค์ช็อกโกแลตช็อกโกแลตนม     80     45       8          1        10               1
# ====  ===============================  =====  =====  ======  =========  ========  ==============
# --------------------------- Day  5  ---------------------------
# CPLEX 22.1.1.0: optimal integer solution; objective 43
# 84 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 43.0
# ---------------------------Breakfast---------------------------
# ====  =======================================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                                     cal    fat    carb    protein    sodium    amount(unit)
# ====  =======================================  =====  =====  ======  =========  ========  ==============
#    0  ดอยคำน้ำฝรั่ง๙๘%                              120      0      30          0         0               1
#    1  ฟาร์มเฮ้าส์สวีทแซนด์วิชแซนด์วิชไส้ครีมนมเนยอัลมอนด์    160     72      18          3       160               1
#    2  โยเกิร์ตเมจิรสสตรอเบอร์รี่                        80     18      13          3        45               1
# ====  =======================================  =====  =====  ======  =========  ========  ==============
# CPLEX 22.1.1.0: optimal integer solution; objective 40
# 68 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 40.0
# ---------------------------Lunch---------------------------
# ====  ===============================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                             cal    fat    carb    protein    sodium    amount(unit)
# ====  ===============================  =====  =====  ======  =========  ========  ==============
#    0  ดอยคำน้ำเสาวรส๕๐%                   120      0      29          0        20               1
#    1  เบงเบงเวเฟอร์สอดไส้ครีมและคาราเมล     120     99      16          1        35               1
#    2  โยเกิร์ตพร้อมดื่มเมจิบัลแกเรียรสกลมกล่อม    110     18      19          5        65               1
# ====  ===============================  =====  =====  ======  =========  ========  ==============
# CPLEX 22.1.1.0: optimal integer solution; objective 40
# 56 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 40.0
# ---------------------------Dinner---------------------------
# ====  ===============================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                             cal    fat    carb    protein    sodium    amount(unit)
# ====  ===============================  =====  =====  ======  =========  ========  ==============
#    0  ดอยคำน้ำเสาวรส๕๐%                   120      0      29          0        20               1
#    1  เบงเบงเวเฟอร์สอดไส้ครีมและคาราเมล     120     99      16          1        35               1
#    2  โยเกิร์ตพร้อมดื่มเมจิบัลแกเรียรสกลมกล่อม    110     18      19          5        65               1
# ====  ===============================  =====  =====  ======  =========  ========  ==============
# --------------------------- Day  6  ---------------------------
# CPLEX 22.1.1.0: optimal integer solution; objective 45
# 12 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 45.0
# ---------------------------Breakfast---------------------------
# ====  ====================================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                                  cal    fat    carb    protein    sodium    amount(unit)
# ====  ====================================  =====  =====  ======  =========  ========  ==============
#    0  นมเปรี้ยวโยเกิร์ตพร้อมดื่มไพเกนกลิ่นสตรอเบอร์รี่     50      0      12          1        35               1
#    1  โยเกิร์ตเมจิวุ้นมะพร้าว                        80     18      13          3        45               1
#    2  โมจิชูครีม                                 669     72      20          2       140               1
# ====  ====================================  =====  =====  ======  =========  ========  ==============
# CPLEX 22.1.1.0: optimal integer solution; objective 42
# 50 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 42.0
# ---------------------------Lunch---------------------------
# ====  =======================================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                                     cal    fat    carb    protein    sodium    amount(unit)
# ====  =======================================  =====  =====  ======  =========  ========  ==============
#    0  ดอยคำน้ำชาเขียวรสต้นตำรับ                       70      0      17          0        10               1
#    1  ฟาร์มเฮ้าส์สวีทแซนด์วิชแซนด์วิชไส้ครีมนมเนยอัลมอนด์    160     72      18          3       160               1
#    2  โยเกิร์ตเมจิมิกซ์เบอร์รี                          120     27      20          4        55               1
# ====  =======================================  =====  =====  ======  =========  ========  ==============
# CPLEX 22.1.1.0: optimal integer solution; objective 44
# 99 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 44.0
# ---------------------------Dinner---------------------------
# ====  ==============================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                            cal    fat    carb    protein    sodium    amount(unit)
# ====  ==============================  =====  =====  ======  =========  ========  ==============
#    0  เซียงไฮ้เวเฟอร์เคลือบครีมรสช็อกโกแลต    170     90      18          1        80               1
#    1  ดอยคำน้ำลิ้นจี่๙๘%                     120      0      31          0        15               1
#    2  โยเกิร์ตเมจิรสธรรมชาติ                 80     27      10          5        80               1
# ====  ==============================  =====  =====  ======  =========  ========  ==============
# --------------------------- Day  7  ---------------------------
# CPLEX 22.1.1.0: optimal integer solution; objective 48
# 47 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 48.0
# ---------------------------Breakfast---------------------------
# ====  ============================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                          cal    fat    carb    protein    sodium    amount(unit)
# ====  ============================  =====  =====  ======  =========  ========  ==============
#    0  เมจิบราวน์โยเกิร์ตรสคาราเมลผสมบุก    130     27      21          4        60               3
# ====  ============================  =====  =====  ======  =========  ========  ==============
# CPLEX 22.1.1.0: optimal integer solution; objective 44
# 107 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 44.0
# ---------------------------Lunch---------------------------
# ====  ==============================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                            cal    fat    carb    protein    sodium    amount(unit)
# ====  ==============================  =====  =====  ======  =========  ========  ==============
#    0  เซียงไฮ้เวเฟอร์เคลือบครีมรสช็อกโกแลต    170     90      18          1        80               1
#    1  ดอยคำน้ำลิ้นจี่๙๘%                     120      0      31          0        15               1
#    2  โยเกิร์ตเมจิสูตรไขมัน0%รสออริจินัล         70      0      13          5        75               1
# ====  ==============================  =====  =====  ======  =========  ========  ==============
# CPLEX 22.1.1.0: optimal integer solution; objective 45
# 49 MIP simplex iterations
# 0 branch-and-bound nodes
# Objective is: 45.0
# ---------------------------Dinner---------------------------
# ====  ==========================  =====  =====  ======  =========  ========  ==============
#   ..  p_name                        cal    fat    carb    protein    sodium    amount(unit)
# ====  ==========================  =====  =====  ======  =========  ========  ==============
#    0  กูลิโกะป๊อกกี้ช๊อกโกแลตอัลมอนด์ครัช    230    117      22          5        55               1
#    1  เจเล่บิวตี้คอลลาเจน                35      0       8          2        25               1
#    2  ดอยคำน้ำกระเจี๊ยบ                110      0      27          0        15               1
# ====  ==========================  =====  =====  ======  =========  ========  ==============

# %% [markdown]
# TEST TEST TEST

# %%
df = pd.DataFrame(data, columns = ['Product','Price','Discount'])

df = df.sample()

print (df)

# %%
i = 1

for i in range(i, iter+1) :
  print ("--------------------------- Day ", i, " ---------------------------")

  ampl.eval(
      r"""
      reset;
      option solver cplex;

      set nutr;
      set id;

      param price {id} > 0;
      param pdf >= 0;
      param m_min {nutr} >= 0;
      param m_max {i in nutr} >= m_min[i];

      param amt {nutr,id} >= 0;

      var Buy {j in id} integer >= 0;

      minimize Total_Cost:  sum {j in id} price[j] * Buy[j];

      subject to Diet {i in nutr}: m_min[i] <= sum {j in id} amt[i,j] * Buy[j] <= m_max[i];
      subject to const1 : sum {j in id} price[j] * Buy[j] <= pdf;""")

  # nutrition condition for male
  if gender == 'm' :
      if age <= 3 :
          ampl.set_data(y3_m, "nutr")
      elif age <= 5 :
          ampl.set_data(y5_m, "nutr")
      elif age <= 8 :
          ampl.set_data(y8_m, "nutr")
      elif age <= 12 :
          ampl.set_data(y12_m, "nutr")
      elif age <= 15 :
          ampl.set_data(y15_m, "nutr")
      elif age <= 18 :
          ampl.set_data(y18_m, "nutr")
      elif age <= 30 :
          ampl.set_data(y30_m, "nutr")
      elif age <= 50 :
          ampl.set_data(y50_m, "nutr")
      elif age <= 60 :
          ampl.set_data(y60_m, "nutr")
      elif age <= 70 :
          ampl.set_data(y70_m, "nutr")
      elif age >= 71 :
          ampl.set_data(y71_m, "nutr") 

  # nutrition condition for female
  elif gender == 'fm' :
      if age <= 3 :
          ampl.set_data(y3_fm, "nutr")
      elif age <= 5 :
          ampl.set_data(y5_fm, "nutr")
      elif age <= 8 :
          ampl.set_data(y8_fm, "nutr")
      elif age <= 12 :
          ampl.set_data(y12_fm, "nutr")
      elif age <= 15 :
          ampl.set_data(y15_fm, "nutr")
      elif age <= 18 :
          ampl.set_data(y18_fm, "nutr")
      elif age <= 30 :
          ampl.set_data(y30_fm, "nutr")
      elif age <= 50 :
          ampl.set_data(y50_fm, "nutr")
      elif age <= 60 :
          ampl.set_data(y60_fm, "nutr")
      elif age <= 70 :
          ampl.set_data(y70_fm, "nutr")
      elif age >= 71 :
          ampl.set_data(y71_fm, "nutr") 
  
  # Send the data from "amt_df" to AMPL and initialize the indexing set "FOOD"
  ampl.set_data(food_df1, "id")
  # Set the values for the parameter "amt" using "amt_df"
  ampl.get_parameter("amt").set_values(amt_df1.unstack())

  ampl.get_parameter("pdf").set_values([pdf])

  # Specify the solver to use (e.g., HiGHS)
  ampl.option["solver"] = "cplex"
  # Solve
  ampl.solve()
  # Stop if the model was not solved
  assert ampl.get_value("solve_result") == "solved"
  # Get objective entity by AMPL name
  totalcost = ampl.get_objective('Total_Cost')
  # Print it
  print("Objective is:", totalcost.value())
  
  print("---------------------------Breakfast---------------------------")
  b_values = ampl.get_variable('Buy').get_values()
  b_values = pd.DataFrame(b_values)
  b_values.columns = ['id', 'amount(unit)']
  result_n = b_values.loc[b_values['amount(unit)'] !=0]
  result = data.merge(result_n, on = ["id"],how = "inner" )
  result = pd.DataFrame(result.iloc[:, [1,2,4,5,6,7,16]])
  print(result.to_markdown(tablefmt="rst"))
  food_df1 = food_df1.drop(result_n['id'])
  amt_df1 = amt_df1.drop(result_n['id'])

  ampl.eval(
      r"""
      reset;
      option solver cplex;

      set nutr;
      set id;

      param price {id} > 0;
      param pdf >= 0;
      param m_min {nutr} >= 0;
      param m_max {i in nutr} >= m_min[i];

      param amt {nutr,id} >= 0;

      var Buy {j in id} integer >= 0;

      minimize Total_Cost:  sum {j in id} price[j] * Buy[j];

      subject to Diet {i in nutr}: m_min[i] <= sum {j in id} amt[i,j] * Buy[j] <= m_max[i];
      subject to const1 : sum {j in id} price[j] * Buy[j] <= pdf;""")

  # nutrition condition for male
  if gender == 'm' :
      if age <= 3 :
          ampl.set_data(y3_m, "nutr")
      elif age <= 5 :
          ampl.set_data(y5_m, "nutr")
      elif age <= 8 :
          ampl.set_data(y8_m, "nutr")
      elif age <= 12 :
          ampl.set_data(y12_m, "nutr")
      elif age <= 15 :
          ampl.set_data(y15_m, "nutr")
      elif age <= 18 :
          ampl.set_data(y18_m, "nutr")
      elif age <= 30 :
          ampl.set_data(y30_m, "nutr")
      elif age <= 50 :
          ampl.set_data(y50_m, "nutr")
      elif age <= 60 :
          ampl.set_data(y60_m, "nutr")
      elif age <= 70 :
          ampl.set_data(y70_m, "nutr")
      elif age >= 71 :
          ampl.set_data(y71_m, "nutr") 

  # nutrition condition for female
  elif gender == 'fm' :
      if age <= 3 :
          ampl.set_data(y3_fm, "nutr")
      elif age <= 5 :
          ampl.set_data(y5_fm, "nutr")
      elif age <= 8 :
          ampl.set_data(y8_fm, "nutr")
      elif age <= 12 :
          ampl.set_data(y12_fm, "nutr")
      elif age <= 15 :
          ampl.set_data(y15_fm, "nutr")
      elif age <= 18 :
          ampl.set_data(y18_fm, "nutr")
      elif age <= 30 :
          ampl.set_data(y30_fm, "nutr")
      elif age <= 50 :
          ampl.set_data(y50_fm, "nutr")
      elif age <= 60 :
          ampl.set_data(y60_fm, "nutr")
      elif age <= 70 :
          ampl.set_data(y70_fm, "nutr")
      elif age >= 71 :
          ampl.set_data(y71_fm, "nutr") 
  
  # 1. Send the data from "amt_df" to AMPL and initialize the indexing set "FOOD"
  ampl.set_data(food_df2, "id")
  # 3. Set the values for the parameter "amt" using "amt_df"
  ampl.get_parameter("amt").set_values(amt_df2.unstack())

  ampl.get_parameter("pdf").set_values([pdf])

  # Specify the solver to use 
  ampl.option["solver"] = "cplex"
  # Solve
  ampl.solve()
  # Stop if the model was not solved
  assert ampl.get_value("solve_result") == "solved"
  # Get objective entity by AMPL name
  totalcost = ampl.get_objective('Total_Cost')
  # Print it
  print("Objective is:", totalcost.value())
  
  print("---------------------------Lunch---------------------------")
  b_values = ampl.get_variable('Buy').get_values()
  b_values = pd.DataFrame(b_values)
  b_values.columns = ['id', 'amount(unit)']
  result_n = b_values.loc[b_values['amount(unit)'] !=0]
  result = data.merge(result_n, on = ["id"],how = "inner" )
  result = pd.DataFrame(result.iloc[:, [1,2,4,5,6,7,16]])
  print(result.to_markdown(tablefmt="rst"))
  food_df2 = food_df2.drop(result_n['id'])
  amt_df2 = amt_df2.drop(result_n['id'])

  ampl.eval(
      r"""
      reset;
      option solver cplex;

      set nutr;
      set id;

      param price {id} > 0;
      param pdf >= 0;
      param m_min {nutr} >= 0;
      param m_max {i in nutr} >= m_min[i];

      param amt {nutr,id} >= 0;

      var Buy {j in id} integer >= 0;

      minimize Total_Cost:  sum {j in id} price[j] * Buy[j];

      subject to Diet {i in nutr}: m_min[i] <= sum {j in id} amt[i,j] * Buy[j] <= m_max[i];
      subject to const1 : sum {j in id} price[j] * Buy[j] <= pdf;""")

  # nutrition condition for male
  if gender == 'm' :
      if age <= 3 :
          ampl.set_data(y3_m, "nutr")
      elif age <= 5 :
          ampl.set_data(y5_m, "nutr")
      elif age <= 8 :
          ampl.set_data(y8_m, "nutr")
      elif age <= 12 :
          ampl.set_data(y12_m, "nutr")
      elif age <= 15 :
          ampl.set_data(y15_m, "nutr")
      elif age <= 18 :
          ampl.set_data(y18_m, "nutr")
      elif age <= 30 :
          ampl.set_data(y30_m, "nutr")
      elif age <= 50 :
          ampl.set_data(y50_m, "nutr")
      elif age <= 60 :
          ampl.set_data(y60_m, "nutr")
      elif age <= 70 :
          ampl.set_data(y70_m, "nutr")
      elif age >= 71 :
          ampl.set_data(y71_m, "nutr") 

  # nutrition condition for female
  elif gender == 'fm' :
      if age <= 3 :
          ampl.set_data(y3_fm, "nutr")
      elif age <= 5 :
          ampl.set_data(y5_fm, "nutr")
      elif age <= 8 :
          ampl.set_data(y8_fm, "nutr")
      elif age <= 12 :
          ampl.set_data(y12_fm, "nutr")
      elif age <= 15 :
          ampl.set_data(y15_fm, "nutr")
      elif age <= 18 :
          ampl.set_data(y18_fm, "nutr")
      elif age <= 30 :
          ampl.set_data(y30_fm, "nutr")
      elif age <= 50 :
          ampl.set_data(y50_fm, "nutr")
      elif age <= 60 :
          ampl.set_data(y60_fm, "nutr")
      elif age <= 70 :
          ampl.set_data(y70_fm, "nutr")
      elif age >= 71 :
          ampl.set_data(y71_fm, "nutr") 
  
  # 1. Send the data from "amt_df" to AMPL and initialize the indexing set "FOOD"
  ampl.set_data(food_df3, "id")
  # 3. Set the values for the parameter "amt" using "amt_df"
  ampl.get_parameter("amt").set_values(amt_df3.unstack())

  ampl.get_parameter("pdf").set_values([pdf])

  # Specify the solver to use
  ampl.option["solver"] = "cplex"
  # Solve
  ampl.solve()
  # Stop if the model was not solved
  assert ampl.get_value("solve_result") == "solved"
  # Get objective entity by AMPL name
  totalcost = ampl.get_objective('Total_Cost')
  # Print it
  print("Objective is:", totalcost.value())

  print("---------------------------Dinner---------------------------")
  b_values = ampl.get_variable('Buy').get_values()
  b_values = pd.DataFrame(b_values)
  b_values.columns = ['id', 'amount(unit)']
  result_n = b_values.loc[b_values['amount(unit)'] !=0]
  result = data.merge(result_n, on = ["id"],how = "inner" )
  result = pd.DataFrame(result.iloc[:, [1,2,4,5,6,7,16]])
  print(result.to_markdown(tablefmt="rst"))
  food_df3 = food_df3.drop(result_n['id'])
  amt_df3 = amt_df3.drop(result_n['id'])

# %%
# # Send the data from "nutr_df" to AMPL and initialize the indexing set "NUTR"
# name = input("What is your name? : ")
# print("Hello " + name + "! To calculate your appropriate nutrition, PLEASE SUBMIT YOUR AGE AND YOUR GENER.")
# age = int(input("Please input your age : "))
# gender = input("Please input your gender (m/f): ")

# %%
# food_df

# %%
# # nutrition condition for male
# if gender == 'm' :
#   if age <= 3 :
#     ampl.set_data(y3_m, "nutr")
#   elif age <= 5 :
#     ampl.set_data(y5_m, "nutr")
#   elif age <= 8 :
#     ampl.set_data(y8_m, "nutr")
#   elif age <= 12 :
#     ampl.set_data(y12_m, "nutr")
#   elif age <= 15 :
#     ampl.set_data(y15_m, "nutr")
#   elif age <= 18 :
#     ampl.set_data(y18_m, "nutr")
#   elif age <= 30 :
#     ampl.set_data(y30_m, "nutr")
#   elif age <= 50 :
#     ampl.set_data(y50_m, "nutr")
#   elif age <= 60 :
#     ampl.set_data(y60_m, "nutr")
#   elif age <= 70 :
#     ampl.set_data(y70_m, "nutr")
#   elif age >= 71 :
#     ampl.set_data(y71_m, "nutr") 

# # nutrition condition for female
# elif gender == 'fm' :
#   if age <= 3 :
#     ampl.set_data(y3_fm, "nutr")
#   elif age <= 5 :
#     ampl.set_data(y5_fm, "nutr")
#   elif age <= 8 :
#     ampl.set_data(y8_fm, "nutr")
#   elif age <= 12 :
#     ampl.set_data(y12_fm, "nutr")
#   elif age <= 15 :
#     ampl.set_data(y15_fm, "nutr")
#   elif age <= 18 :
#     ampl.set_data(y18_fm, "nutr")
#   elif age <= 30 :
#     ampl.set_data(y30_fm, "nutr")
#   elif age <= 50 :
#     ampl.set_data(y50_fm, "nutr")
#   elif age <= 60 :
#     ampl.set_data(y60_fm, "nutr")
#   elif age <= 70 :
#     ampl.set_data(y70_fm, "nutr")
#   elif age >= 71 :
#     ampl.set_data(y71_fm, "nutr")

# %%
# # 1. Send the data from "amt_df" to AMPL and initialize the indexing set "FOOD"
# ampl.set_data(food_df, "id")
# # 3. Set the values for the parameter "amt" using "amt_df"
# ampl.get_parameter("amt").set_values(amt_df.unstack())

# %%
# # Set the value for the parameter "pdf"
# pdf = int(input("Enter money remain: "))
# ampl.get_parameter("pdf").set_values([pdf])

# %%
# # Specify the solver to use (e.g., HiGHS)
# ampl.option["solver"] = "highs"
# # Solve
# ampl.solve()
# # Stop if the model was not solved
# assert ampl.get_value("solve_result") == "solved"
# # Get objective entity by AMPL name
# totalcost = ampl.get_objective('Total_Cost')
# # Print it
# print("Objective is:", totalcost.value())

# %%
# iter = int(input("# of day: "))
# # Send the data from "nutr_df" to AMPL and initialize the indexing set "NUTR"
# name = input("What is your name? : ")
# print("Hello " + name + "! To calculate your appropriate nutrition, PLEASE SUBMIT YOUR AGE AND YOUR GENER.")
# age = int(input("Please input your age : "))
# gender = input("Please input your gender (m/f): ")
# pdf = int(input("Enter money remain: "))

# i = 1

# for i in range(i, iter+1) :
#   print ("i = ", i)

#   ampl.eval(
#       r"""
#       reset;
#       option solver cplex;
#       set nutr;
#       set id;

#       param price {id} > 0;
#       param pdf >= 0;
#       param m_min {nutr} >= 0;
#       param m_max {i in nutr} >= m_min[i], <= m_max[i];

#       param amt {nutr,id} >= 0;

#       var Buy {j in id} integer >= 0;

#       minimize Total_Cost: sum {j in id} price[j] * Buy[j];

#       subject to Diet {i in nutr}: m_min[i] <= sum {j in id} amt[i,j] * Buy[j] <= m_max[i];
#       subject to const1 : sum {j in id} price[j] * Buy[j] <= pdf;""")

#   # nutrition condition for male
#   if gender == 'm' :
#       if age <= 3 :
#           ampl.set_data(y3_m, "nutr")
#       elif age <= 5 :
#           ampl.set_data(y5_m, "nutr")
#       elif age <= 8 :
#           ampl.set_data(y8_m, "nutr")
#       elif age <= 12 :
#           ampl.set_data(y12_m, "nutr")
#       elif age <= 15 :
#           ampl.set_data(y15_m, "nutr")
#       elif age <= 18 :
#           ampl.set_data(y18_m, "nutr")
#       elif age <= 30 :
#           ampl.set_data(y30_m, "nutr")
#       elif age <= 50 :
#           ampl.set_data(y50_m, "nutr")
#       elif age <= 60 :
#           ampl.set_data(y60_m, "nutr")
#       elif age <= 70 :
#           ampl.set_data(y70_m, "nutr")
#       elif age >= 71 :
#           ampl.set_data(y71_m, "nutr") 

#   # nutrition condition for female
#   elif gender == 'fm' :
#       if age <= 3 :
#           ampl.set_data(y3_fm, "nutr")
#       elif age <= 5 :
#           ampl.set_data(y5_fm, "nutr")
#       elif age <= 8 :
#           ampl.set_data(y8_fm, "nutr")
#       elif age <= 12 :
#           ampl.set_data(y12_fm, "nutr")
#       elif age <= 15 :
#           ampl.set_data(y15_fm, "nutr")
#       elif age <= 18 :
#           ampl.set_data(y18_fm, "nutr")
#       elif age <= 30 :
#           ampl.set_data(y30_fm, "nutr")
#       elif age <= 50 :
#           ampl.set_data(y50_fm, "nutr")
#       elif age <= 60 :
#           ampl.set_data(y60_fm, "nutr")
#       elif age <= 70 :
#           ampl.set_data(y70_fm, "nutr")
#       elif age >= 71 :
#           ampl.set_data(y71_fm, "nutr") 
  
#   # 1. Send the data from "amt_df" to AMPL and initialize the indexing set "FOOD"
#   ampl.set_data(food_df1, "id")
#   # 3. Set the values for the parameter "amt" using "amt_df"
#   ampl.get_parameter("amt").set_values(amt_df1.unstack())

#   ampl.get_parameter("pdf").set_values([pdf])

#   # Specify the solver to use
#   ampl.option["solver"] = "cplex"
#   # Solve
#   ampl.solve()
#   # Stop if the model was not solved
#   assert ampl.get_value("solve_result") == "solved"
#   # Get objective entity by AMPL name
#   totalcost = ampl.get_objective('Total_Cost')
#   # Print it
#   print("Objective is:", totalcost.value())
#   ampl.display("Buy")
